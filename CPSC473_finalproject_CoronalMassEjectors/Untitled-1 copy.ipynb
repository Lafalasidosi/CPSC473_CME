# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv('data.txt', delim_whitespace=True)
data.head()
# Out:
# C:\Users\lafal\AppData\Local\Temp\ipykernel_21236\4144257189.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv('data.txt', delim_whitespace=True)
#              Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  \
# 0  2025-03-13:00:00:00       0    7.21    7.03    7.26    2.60    1.66
# 1  2025-03-13:00:05:00       0    6.98    6.95    7.03    2.03    0.53
# 2  2025-03-13:00:10:00       0    6.64    6.26    6.82    3.81    2.98
# 3  2025-03-13:00:15:00       0    6.27    5.25    6.51    3.85    2.89
# 4  2025-03-13:00:20:00       0    6.55    6.50    6.73    5.86    5.55
#
#    Bx-max  By-med  By-min  ...  Theta-max  Dens-med  Dens-min  Dens-max  \
# 0    3.09   -0.74   -2.51  ...     -56.57      0.18      0.11      0.26
# 1    2.41   -0.43   -0.83  ...     -69.39      0.16      0.10      0.39
# ...

# %%
data.describe()
# Out:
#             Source        Bt-med        Bt-min        Bt-max        Bx-med  \
# count  1941.000000   1941.000000   1941.000000   1941.000000   1941.000000
# mean      0.368367  -3084.909928  -3085.170077  -3084.760392  -3088.221710
# std       0.500318  17313.307998  17313.261529  17313.334710  17312.716443
# min      -1.000000 -99999.000000 -99999.000000 -99999.000000 -99999.000000
# 25%       0.000000      4.920000      4.730000      5.050000      1.100000
# 50%       0.000000      6.170000      5.740000      6.390000      3.100000
# 75%       1.000000      7.240000      7.020000      7.400000      4.570000
# max       2.000000     12.840000     12.820000     12.930000      9.950000
#
#              Bx-min        Bx-max        By-med        By-min        By-max  \
# count   1941.000000   1941.000000   1941.000000   1941.000000   1941.000000
# mean   -3088.927357  -3087.608217  -3093.686043  -3094.502813  -3092.778903
# ...

# %% [markdown]
# Just remove all entries with wonky entries (-99999.00000)

# %%
data = data[data['Bt-med'] > -99998.0]
data.describe()
# Out:
#             Source       Bt-med       Bt-min       Bt-max       Bx-med  \
# count  1881.000000  1881.000000  1881.000000  1881.000000  1881.000000
# mean      0.357788     6.448607     6.180159     6.602913     3.031186
# std       0.487181     1.840343     1.897259     1.825082     2.511887
# min       0.000000     2.940000     1.650000     3.630000    -4.270000
# 25%       0.000000     4.980000     4.800000     5.130000     1.320000
# 50%       0.000000     6.290000     5.860000     6.510000     3.210000
# 75%       1.000000     7.280000     7.050000     7.430000     4.600000
# max       2.000000    12.840000    12.820000    12.930000     9.950000
#
#             Bx-min       Bx-max       By-med       By-min       By-max  ...  \
# count  1881.000000  1881.000000  1881.000000  1881.000000  1881.000000  ...
# mean      2.303030     3.664248    -2.607448    -3.450271    -1.671372  ...
# std       2.700764     2.367306     2.684215     2.464531     2.882516  ...
# ...

# %%
data.dtypes
# Out:
# Timestamp     object
# Source         int64
# Bt-med       float64
# Bt-min       float64
# Bt-max       float64
# Bx-med       float64
# Bx-min       float64
# Bx-max       float64
# By-med       float64
# By-min       float64
# By-max       float64
# Bz-med       float64
# Bz-min       float64
# Bz-max       float64
# Phi-mean     float64
# Phi-min      float64
# Phi-max      float64
# Theta-med    float64
# Theta-min    float64
# Theta-max    float64
# Dens-med     float64
# Dens-min     float64
# Dens-max     float64
# Speed-med    float64
# Speed-min    float64
# Speed-max    float64
# Temp-med       int64
# Temp-min       int64
# Temp-max       int64
# dtype: object

# %%
data['Timestamp'] = data['Timestamp'].apply(lambda x: pd.to_datetime(x, format='%Y-%m-%d:%H:%M:%S'))

# %%
data.dtypes
# Out:
# Timestamp    datetime64[ns]
# Source                int64
# Bt-med              float64
# Bt-min              float64
# Bt-max              float64
# Bx-med              float64
# Bx-min              float64
# Bx-max              float64
# By-med              float64
# By-min              float64
# By-max              float64
# Bz-med              float64
# Bz-min              float64
# Bz-max              float64
# Phi-mean            float64
# Phi-min             float64
# Phi-max             float64
# Theta-med           float64
# Theta-min           float64
# Theta-max           float64
# Dens-med            float64
# Dens-min            float64
# Dens-max            float64
# Speed-med           float64
# Speed-min           float64
# Speed-max           float64
# Temp-med              int64
# Temp-min              int64
# Temp-max              int64
# dtype: object

# %%
data['Timestamp'] = data['Timestamp'].apply(lambda x: pd.Timestamp.timestamp(x))

# %% [markdown]
# # Forecasting

# %%
timeSeries = data['Timestamp']
tempvstime = data.loc[:, ['Timestamp', 'Temp-med']]
tempvstime
timesasfloats = data['Timestamp'].apply(lambda x: pd.Timestamp.timestamp(x))
timesasfloats

# %%
pd.Timestamp.timestamp(timeSeries.loc[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pd.Timestamp.timestamp(timeSeries.loc[1])
#
# File timestamps.pyx:1146, in pandas._libs.tslibs.timestamps._Timestamp.timestamp()
#
# File dtypes.pyx:689, in pandas._libs.tslibs.dtypes.periods_per_second()
#
# File np_datetime.pyx:599, in pandas._libs.tslibs.np_datetime.get_conversion_factor()
#
# ValueError: from_unit must be <= to_unit
